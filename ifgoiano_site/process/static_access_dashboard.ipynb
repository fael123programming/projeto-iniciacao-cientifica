# %% [markdown]
# # Leitura do dataset mais recente

# %%
import pandas as pd
import os
from datetime import datetime

pd.set_option('display.float_format', lambda x: '%.2f' % x)

def get_datetime(dataset_name):
    split_dataset_name = dataset_name.split('_')
    year = int(split_dataset_name[2])
    month = int(split_dataset_name[3])
    day = int(split_dataset_name[4])
    return datetime(year=year, month=month, day=day)

with os.scandir('../datasets/') as dir_entries:
    ### Get the latest produced dataset for analysis.
    filename = dir_entries.__next__().name  # First filename.
    for dir_entry in dir_entries:
        dt_from_filename = get_datetime(filename)
        dt_from_dir_entry = get_datetime(dir_entry.name)
        if dt_from_dir_entry > dt_from_filename:
            filename = dir_entry.name
    ##############################################
data = pd.read_csv(f'../datasets/{filename}')
data = data.dropna()

# %% [markdown]
# # Dashboard: Análise stática de acessos

# %%
from matplotlib import pyplot, gridspec

fig = pyplot.figure(figsize=(50, 350))
specs = gridspec.GridSpec(ncols=1, nrows=41, figure=fig)

# Graficos de quantidade de publicacoes.

ax1 = fig.add_subplot(specs[0, 0])
ax1_data = data[['titulo', 'imagens']].groupby('imagens').count().reset_index().sort_values('titulo')
pyplot.rcParams['figure.figsize'] = (18, 10)
pyplot.title('Quantidade de publicações agrupadas pelo número de imagens')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Quantidade de imagens')
pyplot.ylabel('Quantidade de publicações')
ax1.bar(ax1_data['imagens'], ax1_data['titulo'])

ax2 = fig.add_subplot(specs[2, 0])
ax2_data = data[['acessos', 'imagens']].groupby('imagens').sum().reset_index().sort_values('acessos')
pyplot.ticklabel_format(style='plain')
pyplot.title('Soma da quantidade total de acessos agrupando as publicações pelo número de imagens')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Quantidade de imagens')
pyplot.ylabel('Soma total de acessos')
ax2.bar(ax2_data['imagens'], ax2_data['acessos'])

ax3 = fig.add_subplot(specs[4, 0])
ax3_data = data[['acessos', 'imagens']].groupby('imagens').mean().reset_index().sort_values('acessos')
pyplot.ticklabel_format(style='plain')
pyplot.title('Média da quantidade total de acessos agrupando as publicações pelo número de imagens')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Quantidade de imagens')
pyplot.ylabel('Média de acessos')
ax3.bar(ax3_data['imagens'], ax3_data['acessos'])

ax4 = fig.add_subplot(specs[6, 0])
ax4_data = data[['titulo', 'tem_imagem_perfil']].groupby('tem_imagem_perfil').count().reset_index().sort_values('titulo')
pyplot.title('Quantidade de publicações que possuem e não imagem de perfil')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Tem imagem de perfil?')
pyplot.ylabel('Quantidade de publicações')
ax4.bar(ax4_data['tem_imagem_perfil'], ax4_data['titulo'])

ax5 = fig.add_subplot(specs[8, 0])
ax5_data = data[['acessos', 'tem_imagem_perfil']].groupby('tem_imagem_perfil').sum().reset_index().sort_values('acessos')
pyplot.ticklabel_format(style='plain')
pyplot.title('Soma da quantidade total de acessos agrupando as publicações por aquelas que tem ou não imagem de perfil')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Tem imagem de perfil?')
pyplot.ylabel('Total de acessos')
ax5.bar(ax5_data['tem_imagem_perfil'], ax5_data['acessos'])

ax6 = fig.add_subplot(specs[10, 0])
ax6_data = data[['acessos', 'tem_imagem_perfil']].groupby('tem_imagem_perfil').mean().reset_index().sort_values('acessos')
pyplot.title('Média da quantidade total de acessos agrupando as publicações por aquelas que tem ou não imagem de perfil')
pyplot.rcParams.update({'font.size': 30})
pyplot.ticklabel_format(style='plain')
pyplot.xlabel('Tem imagem de perfil?')
pyplot.ylabel('Média de acessos')
ax6.bar(ax6_data['tem_imagem_perfil'], ax6_data['acessos'])

ax7 = fig.add_subplot(specs[12, 0])
ax7_data = data[['titulo', 'dia_semana']].groupby('dia_semana').count().reset_index().sort_values('titulo')
pyplot.title('Quantidade de publicações por dia da semana')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Dia da semana')
pyplot.ylabel('Quantidade de publicações')
ax7.bar(ax7_data['dia_semana'], ax7_data['titulo'])

ax8 = fig.add_subplot(specs[14, 0])
ax8_data = data[['acessos', 'dia_semana']].groupby('dia_semana').sum().reset_index().sort_values('acessos')
pyplot.ticklabel_format(style='plain')
pyplot.title('Soma do total de acessos agrupando as publicações pelo dia da semana')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Dia da semana')
pyplot.ylabel('Soma do total de acessos')
ax8.bar(ax8_data['dia_semana'], ax8_data['acessos'])

ax9 = fig.add_subplot(specs[16, 0])
ax9_data = data[['acessos', 'dia_semana']].groupby('dia_semana').mean().reset_index().sort_values('acessos')
pyplot.ticklabel_format(style='plain')
pyplot.title('Média de acessos agrupando as publicações por dia da semana')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Dia da semana')
pyplot.ylabel('Média de acessos')
ax9.bar(ax9_data['dia_semana'], ax9_data['acessos'])

ax10 = fig.add_subplot(specs[18, 0])
ax10_data = data[['titulo', 'periodo_dia']].groupby('periodo_dia').count().reset_index().sort_values('titulo')
pyplot.ticklabel_format(style='plain')
pyplot.title('Quantidade de publicações por cada período do dia')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Período do dia')
pyplot.ylabel('Quantidade de publicações')
ax10.bar(ax10_data['periodo_dia'], ax10_data['titulo'])

ax11 = fig.add_subplot(specs[20, 0])
ax11_data = data[['acessos', 'periodo_dia']].groupby('periodo_dia').sum().reset_index().sort_values('acessos')
pyplot.ticklabel_format(style='plain')
pyplot.title('Soma do total de acessos agrupando as publicações por período do dia')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Período do dia')
pyplot.ylabel('Soma do total de acessos')
ax11.bar(ax11_data['periodo_dia'], ax11_data['acessos'])

ax12 = fig.add_subplot(specs[22, 0])
ax12_data = data[['acessos', 'periodo_dia']].groupby('periodo_dia').mean().reset_index().sort_values('acessos')
pyplot.ticklabel_format(style='plain')
pyplot.title('Média de acessos agrupando as publicações por período do dia')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Período do dia')
pyplot.ylabel('Média de acessos')
ax12.bar(ax12_data['periodo_dia'], ax12_data['acessos'])

ax13 = fig.add_subplot(specs[24, 0])
ax13_data = data[['titulo', 'dia_semana', 'periodo_dia']].groupby(['dia_semana', 'periodo_dia']).count().reset_index().sort_values('titulo')
ax13_data['dia_semana_periodo_dia'] = ax13_data['dia_semana'] + '/' + ax13_data['periodo_dia']
ax13_data = ax13_data.drop(['dia_semana', 'periodo_dia'], axis=1)
pyplot.ticklabel_format(style='plain')
pyplot.title('Quantidade de publicações por dia da semana e período do dia')
pyplot.rcParams.update({'font.size': 30})
pyplot.xticks(rotation=90)
pyplot.xlabel('Dia da semana/período do dia')
pyplot.ylabel('Quantidade de publicações')
ax13.bar(ax13_data['dia_semana_periodo_dia'], ax13_data['titulo'])

ax14 = fig.add_subplot(specs[26, 0])
ax14_data = data[['acessos', 'dia_semana', 'periodo_dia']].groupby(['dia_semana', 'periodo_dia']).sum().reset_index().sort_values('acessos')
ax14_data['dia_semana_periodo_dia'] = ax14_data['dia_semana'] + '/' + ax14_data['periodo_dia']
ax14_data = ax14_data.drop(['dia_semana', 'periodo_dia'], axis=1)
pyplot.ticklabel_format(style='plain')
pyplot.title('Soma do total de acessos agrupando as publicações por dia da semana e período do dia')
pyplot.rcParams.update({'font.size': 30})
pyplot.xticks(rotation=90)
pyplot.xlabel('Dia da semana/período do dia')
pyplot.ylabel('Soma total de acessos')
ax14.bar(ax14_data['dia_semana_periodo_dia'], ax14_data['acessos'])

ax15 = fig.add_subplot(specs[28, 0])
ax15_data = data[['acessos', 'dia_semana', 'periodo_dia']].groupby(['dia_semana', 'periodo_dia']).mean().reset_index().sort_values('acessos')
ax15_data['dia_semana_periodo_dia'] = ax15_data['dia_semana'] + '/' + ax15_data['periodo_dia']
ax15_data = ax15_data.drop(['dia_semana', 'periodo_dia'], axis=1)
pyplot.ticklabel_format(style='plain')
pyplot.title('Média de acessos agrupando as publicações por dia da semana e período do dia')
pyplot.rcParams.update({'font.size': 30})
pyplot.xticks(rotation=90)
pyplot.xlabel('Dia da semana/período do dia')
pyplot.ylabel('Média de acessos')
ax15.bar(ax15_data['dia_semana_periodo_dia'], ax15_data['acessos'])

ax16 = fig.add_subplot(specs[30, 0])
data['ano'] = pd.to_datetime(data['data_hora']).dt.strftime('%Y')
ax16_data = data[['titulo', 'ano']].groupby('ano').count().reset_index().sort_values('titulo')
pyplot.title('Quantidade de publicações por ano')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Ano')
pyplot.ylabel('Quantidade de publicações')
ax16.bar(ax16_data['ano'], ax16_data['titulo'])

ax17 = fig.add_subplot(specs[32, 0])
data['ano'] = pd.to_datetime(data['data_hora']).dt.strftime('%Y')
ax17_data = data[['acessos', 'ano']].groupby('ano').sum().reset_index().sort_values('acessos')
pyplot.title('Soma do total de acessos agrupando as publicações por ano')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Ano')
pyplot.ylabel('Soma do total de acessos')
ax17.bar(ax17_data['ano'], ax17_data['acessos'])

ax18 = fig.add_subplot(specs[34, 0])
data['ano'] = pd.to_datetime(data['data_hora']).dt.strftime('%Y')
ax18_data = data[['acessos', 'ano']].groupby('ano').mean().reset_index().sort_values('acessos')
pyplot.title('Média de acessos agrupando as publicações por ano')
pyplot.rcParams.update({'font.size': 30})
pyplot.xlabel('Ano')
pyplot.ylabel('Média de acessos')
ax18.bar(ax18_data['ano'], ax18_data['acessos'])

ax19 = fig.add_subplot(specs[36, 0])
data['ano_mes'] = pd.to_datetime(data['data_hora']).dt.strftime('%Y-%m')
ax19_data = data[['titulo', 'ano_mes']].groupby('ano_mes').count().reset_index().sort_values('titulo')
pyplot.rcParams['figure.figsize'] = (18, 10)
pyplot.rcParams.update({'font.size': 30})
pyplot.title('Quantidade de publicações por ano-mes')
pyplot.xticks(rotation=90)
pyplot.xlabel('Ano-mes')
pyplot.ylabel('Quantidade de publicações')
ax19.bar(ax19_data['ano_mes'], ax19_data['titulo'])

ax20 = fig.add_subplot(specs[38, 0])
data['ano_mes'] = pd.to_datetime(data['data_hora']).dt.strftime('%Y-%m')
ax20_data = data[['acessos', 'ano_mes']].groupby('ano_mes').sum().reset_index().sort_values('acessos')
pyplot.rcParams['figure.figsize'] = (18, 10)
pyplot.rcParams.update({'font.size': 30})
pyplot.title('Soma do total de acessos agrupando as publicações por ano-mes')
pyplot.xticks(rotation=90)
pyplot.xlabel('Ano-mes')
pyplot.ylabel('Soma do total de acessos')
ax20.bar(ax20_data['ano_mes'], ax20_data['acessos'])

ax21 = fig.add_subplot(specs[40, 0])
data['ano_mes'] = pd.to_datetime(data['data_hora']).dt.strftime('%Y-%m')
ax21_data = data[['acessos', 'ano_mes']].groupby('ano_mes').mean().reset_index().sort_values('acessos')
pyplot.rcParams['figure.figsize'] = (18, 10)
pyplot.rcParams.update({'font.size': 30})
pyplot.title('Média de acessos agrupando as publicações por ano-mes')
pyplot.xticks(rotation=90)
pyplot.xlabel('Ano-mes')
pyplot.ylabel('Média de acessos')
ax21.bar(ax21_data['ano_mes'], ax21_data['acessos'])
# Out:
# <BarContainer object of 92 artists>
